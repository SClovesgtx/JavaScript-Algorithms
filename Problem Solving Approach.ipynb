// %% [markdown]
// ![image.png](attachment:image.png)

// %%
function charCout(str) {
    var result = {};
    for(let i=0; i < str.length; i++) {
        var char = str[i];
        if(result[char] > 0){
            result[char]++;
        } else {
            result[char] = 1
        };
    };
    
    return result;
}

// %%
charCout("HelLo 123 # b")
// Out:
// {
//   '1': 1,
//   '2': 1,
//   '3': 1,
//   H: 1,
//   e: 1,
//   l: 1,
//   L: 1,
//   o: 1,
//   ' ': 3,
//   '#': 1,
//   b: 1
// }

// %%
function charCout2(str) {
    var result = {};
    for(let i=0; i < str.length; i++) {
        var char = str[i].toLowerCase();
        if (/[a-z0-9]/.test(char)) {
            if(result[char] > 0){
                result[char]++;
            } else {
                result[char] = 1
            };
        }
    };
    
    return result;
}

// %%
charCout2("hello 123 # b")
// Out:
// { '1': 1, '2': 1, '3': 1, h: 1, e: 1, l: 2, o: 1, b: 1 }

// %%
function charCout3(str) {
    var result = {};
    for(var char of str) {
        var char = char.toLowerCase()
        if (/[a-z0-9]/.test(char)) {
            if(result[char] > 0){
                result[char]++;
            } else {
                result[char] = 1
            };
        }
    };
    
    return result;
}

// %%
charCout3("djasgd")
// Out:
// { d: 2, j: 1, a: 1, s: 1, g: 1 }

// %%
function charCout4(str) {
    var result = {};
    for(var char of str) {
        var char = char.toLowerCase()
        if (/[a-z0-9]/.test(char)) {
           result[char] = ++result[char] || 1;
        }
    };
    
    return result;
}

// %%
charCout4("hello 123 # b p")
// Out:
// { '1': 1, '2': 1, '3': 1, h: 1, e: 1, l: 2, o: 1, b: 1, p: 1 }

// %%
function isAlphaNumeric(char){
    var code = char.charCodeAt(0)
    if (!(code > 47 && code < 58) && // numeric (0-9)
        !(code > 64 && code < 91) && // upper Alpha A-Z
        !(code > 96 && code < 123) // lower Alpha a-z
       ) { return false}
    return true
}

function charCout5(str) {
    var result = {};
    for(var char of str) {
        var char = char.toLowerCase()
        if (isAlphaNumeric(char)) {
           result[char] = ++result[char] || 1;
        }
    };
    
    return result;
}

// %%
charCout5("HeLlo 123 # b p")
// Out:
// { '1': 1, '2': 1, '3': 1, h: 1, e: 1, l: 2, o: 1, b: 1, p: 1 }
